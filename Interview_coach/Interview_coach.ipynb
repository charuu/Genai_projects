# %%
import os
import json
import tiktoken
from openai import OpenAI
from pydantic import BaseModel, Field, ValidationError
from typing import Optional

# Set your API key
os.environ["OPENAI_API_KEY"] = "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"  # replace with your key
client = OpenAI()

print("Setup complete.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
#       2 import json
# ----> 3 import tiktoken
#       4 from openai import OpenAI
#       5 from pydantic import BaseModel, Field, ValidationError
#       6 from typing import Optional
#
# ModuleNotFoundError: No module named 'tiktoken'
